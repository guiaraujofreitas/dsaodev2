# %% [markdown]
# # IMPORTS

# %%
import re
import requests
import pandas as pd
import numpy as np
import math
from bs4 import BeautifulSoup
from datetime import datetime

# %% [markdown]
# # DATA COLLECT

# %%
#PARAMENTS
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36 OPR/37.0.2178.54'}


#link princial do modelo de roupa que pŕeciso
url= 'https://www2.hm.com/en_us/men/products/jeans.html'

#REQUEST TO URL
page = requests.get( url, headers=headers )


#BEAUTIFUL OBJECT
soup = BeautifulSoup(page.text, 'html.parser')

# ================================ PRODUCT DATA =========== # 

products = soup.find( 'ul', class_='products-listing small' )


#list of products
products_list= products.find_all ('article',class_="hm-product-item")


#product id

product_id = [p.get('data-articlecode') for p in products_list]

#product category

products_category= [p.get('data-category') for p in products_list]

#product name 

#extraction all the name 
products_list_2=  products.find_all('a', class_='link')

products_name =[p.get_text('link') for p in products_list_2]

#product price

#extraction informations of price
products_list_3 = products.find_all('span', class_='price regular')

#find all the price in page
products_price= [p.get_text('price_regular') for p in products_list_3]

data = pd.DataFrame([product_id,products_category,products_name,products_price]).T

data.columns = ['product_id','products_category','products_name','products_price']

data['scrapy_datetime'] = datetime.now().strftime('%Y-%m-%d-%H-%M:%S')

# %%
data.shape
# Out:
# (36, 5)

# %%
data.head()
# Out:
#    product_id  products_category         products_name products_price  \
# 0  1024256001     men_jeans_slim            Slim Jeans        $ 19.99
# 1  1008549006  men_jeans_regular         Regular Jeans        $ 19.99
# 2  1004199004   men_jeans_skinny  Skinny Cropped Jeans        $ 29.99
# 3  0985159001   men_jeans_skinny          Skinny Jeans        $ 19.99
# 4  0690449022   men_jeans_ripped          Skinny Jeans        $ 39.99
#
#        scrapy_datetime
# 0  2022-05-12-15-23:02
# 1  2022-05-12-15-23:02
# 2  2022-05-12-15-23:02
# 3  2022-05-12-15-23:02
# 4  2022-05-12-15-23:02

# %% [markdown]
# # DATA  COLLECT BY PRODUCT

# %%
#key browser
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36 OPR/37.0.2178.54'}

#empty Data Frame (to insert the joins)
df_compositions= pd.DataFrame()

aux= []

cols= ['Composition','Size','Art. No.','Fit','messages.garmentLength','messages.waistRise',
'Care instructions',
 'Material',
 'Description',
 'Imported',
 'Concept',
 'Nice to know']
    
df_pattern = pd.DataFrame( columns=  cols )

#df_pattern = pd.DataFrame( columns=['Size','Art. No.','Composition'] )


#API Requests
for i in range(len(data)):
    
    url= 'https://www2.hm.com/en_us/productpage.'+ data.loc[i,'product_id'] +'.html'
    #url= 'https://www2.hm.com/en_us/productpage.'+ '1024256001' +'.html'
    
    #print('Product:{}'.format(url))
    
    
    page = requests.get( url, headers=headers )

    #Beautifull Souo object
    soup= BeautifulSoup(page.text,'html.parser')

    ### ===================== color name ======================

    products_list= soup.find_all('a',class_='filter-option miniature active') + soup.find_all('a',class_='filter-option miniature') 

    #product id
    products_id = [p.get('data-articlecode') for p in products_list]

    #color name
    color_name = [p.get('data-color') for p in products_list]

    #create data frame

    df_color = pd.DataFrame([products_id,color_name]).T

    #rename the columns of DF
    df_color.columns= ['Art. No.','color_name']
    
    
    for j in range(len(df_color)):
        url2= 'https://www2.hm.com/en_us/productpage.'+ df_color.loc[j,'Art. No.'] +'.html'
        #print( 'Color: {}'.format( url2 ) )
        
    
        page = requests.get( url2, headers=headers )

        #Beautifull Souo object
        soup= BeautifulSoup(page.text,'html.parser')
        
        #=========================product name ==============================
        product_name = soup.find_all('h1',class_='primary product-item-headline')
        product_name = product_name[0].get_text()
        
        # ==================== product price ======================= #
        
        product_price= soup.find_all('div',class_='primary-row product-item-price')
        product_price = re.findall(r'\d+?.\d+',product_price[0].get_text())[0]
       
        
        
        #create new colum styly_id
        #df_color['stlye_id'] = df_color['product_id'].apply(lambda x: x[:-3])

        #create new colum color_id
        #df_color['color_id'] = df_color['product_id'].apply(lambda x: x[-3:])

        # ============================== composition =============================== #

        #composition
        composition_list= soup.find_all('div', class_ = 'details-attributes-list-item')
        
        #composition_list = soup.find_all('dd','details-list-item')
        #product_composition = composition_list[3]

        product_composition = [list(filter (None, p.get_text().split('\n') ) ) for p in composition_list]
        

        if product_composition != []:

            #created the dataframe aux
            df_composition= pd.DataFrame(product_composition).T
        
            
            #renome the columns
            df_composition.columns= df_composition.iloc[0]

            #delete the first row and delete the columns that is the empty
            df_composition= df_composition.iloc[1:].fillna(method='ffill')

            
            
            #select columns 
            #df_composition= df_composition[['Composition','Art. No.']]

            #delete the first row and delete the columns that is the empty
            #df_composition= df_aux.iloc[1:3]

            #copying the code and the model to row the below
            #df_composition = df_composition.fillna(method='ffill')


            #rename the data frame to a new variable
            #df_composition = df_composition.copy(True)

            #remove pocket lining, shell and lining
            df_composition['Composition'] = df_composition['Composition'].replace('Pocket lining:','',regex=True)
            df_composition['Composition'] = df_composition['Composition'].replace('Shell:','',regex=True)
            df_composition['Composition'] = df_composition['Composition'].replace('Lining:','',regex=True)
        
       

    
            # garantee the same number of columns
            df_composition = pd.concat( [df_pattern, df_composition], axis=0 )

            #rename the columns 
            #df_composition.columns = ['composition', 'size', 'art. no.', 'fit', 'messages.garmentLength',
            #'messages.waistRise', 'care instructions', 'material', 'description',
            #'imported', 'concept', 'nice to know','more sustainable materials']

            #create new colum styly_id
            #df_composition['stlye_id'] =df_composition['Art. No.'].apply(lambda x: x[:-3])

            #create new colum color_id
            #df_composition['color_id'] = df_composition['Art. No.'].apply(lambda x: x[-3:])

            #keep new columns if it shows
            aux= aux + df_composition.columns.tolist()

    
            #merge dataframe of color and composition 
            df_composition= pd.merge(df_composition,df_color, how='left', on ='Art. No.')
            


            #all products 
            df_compositions = pd.concat([df_composition,df_compositions], axis=0)

        
        
    else:
        None

#select just columns necessary
df_compositions= df_compositions[['Art. No.','Composition','color_name','Size','Fit']]

#rename columns
df_compositions.rename(columns = {'Art. No.':'product_id','Composition':'composition','Size':'size','Fit':'fit'},inplace=True)

# Join Showroom data + details

df_compositions['stlye_id'] = df_compositions['product_id'].apply( lambda x: x[:-3] )
df_compositions['color_id'] = df_compositions['product_id'].apply( lambda x: x[-3:] )

df_compositionsi['scrapy_datetime'] = datetime.now().strftime('%Y-%m-%d-%H-%M:%S')
# Out:
#                Composition Size    Art. No.         Fit  \
# 0   Cotton 99%, Spandex 1%  NaN  0985159001  Skinny fit
# 1              Cotton 100%  NaN  0985159001  Skinny fit
# 2              Cotton 100%  NaN  0985159001  Skinny fit
# 3              Cotton 100%  NaN  0985159001  Skinny fit
# 4              Cotton 100%  NaN  0985159001  Skinny fit
# 5              Cotton 100%  NaN  0985159001  Skinny fit
# 6              Cotton 100%  NaN  0985159001  Skinny fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
#
#                                    Care instructions Material  Description  \
# 0               Only non-chlorine bleach when needed    Denim        Black
# 1                                        Medium iron    Denim  Solid-color
# 2                                           Line dry    Denim  Solid-color
# 3                                 Can be dry cleaned    Denim  Solid-color
# 4                                  Machine wash cold    Denim  Solid-color
# 5                              Wash with like colors    Denim  Solid-color
# 6  The color of this denim may transfer onto ligh...    Denim  Solid-color
#
#   Imported Concept         Nice to know More sustainable materials color_name
# 0      Yes   DENIM  environmentalMarker        Recycled cotton 20%      Black
# 1      Yes   DENIM  environmentalMarker        Recycled cotton 20%      Black
# 2      Yes   DENIM  environmentalMarker        Recycled cotton 20%      Black
# 3      Yes   DENIM  environmentalMarker        Recycled cotton 20%      Black
# 4      Yes   DENIM  environmentalMarker        Recycled cotton 20%      Black
# 5      Yes   DENIM  environmentalMarker        Recycled cotton 20%      Black
# 6      Yes   DENIM  environmentalMarker        Recycled cotton 20%      Black
#                Composition Size    Art. No.         Fit  \
# 0   Cotton 99%, Spandex 1%  NaN  0985159002  Skinny fit
# 1              Cotton 100%  NaN  0985159002  Skinny fit
# 2              Cotton 100%  NaN  0985159002  Skinny fit
# 3              Cotton 100%  NaN  0985159002  Skinny fit
# 4              Cotton 100%  NaN  0985159002  Skinny fit
# 5              Cotton 100%  NaN  0985159002  Skinny fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
#
#                       Care instructions Material  Description Imported  \
# 0  Only non-chlorine bleach when needed    Denim   Denim blue      Yes
# 1                           Medium iron    Denim  Solid-color      Yes
# 2                     Machine wash cool    Denim  Solid-color      Yes
# 3                 Wash with like colors    Denim  Solid-color      Yes
# 4                              Line dry    Denim  Solid-color      Yes
# 5                    Can be dry cleaned    Denim  Solid-color      Yes
#
#   Concept         Nice to know More sustainable materials  color_name
# 0   DENIM  environmentalMarker        Recycled cotton 20%  Denim blue
# 1   DENIM  environmentalMarker        Recycled cotton 20%  Denim blue
# 2   DENIM  environmentalMarker        Recycled cotton 20%  Denim blue
# 3   DENIM  environmentalMarker        Recycled cotton 20%  Denim blue
# 4   DENIM  environmentalMarker        Recycled cotton 20%  Denim blue
# 5   DENIM  environmentalMarker        Recycled cotton 20%  Denim blue
#                   Composition Size    Art. No.         Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  0985159003  Skinny fit
# 1   Polyester 63%, Cotton 37%  NaN  0985159003  Skinny fit
# 2   Polyester 63%, Cotton 37%  NaN  0985159003  Skinny fit
# 3   Polyester 63%, Cotton 37%  NaN  0985159003  Skinny fit
# 4   Polyester 63%, Cotton 37%  NaN  0985159003  Skinny fit
# 5   Polyester 63%, Cotton 37%  NaN  0985159003  Skinny fit
# 6   Polyester 63%, Cotton 37%  NaN  0985159003  Skinny fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
#
#                                    Care instructions Material  Description  \
# 0               Only non-chlorine bleach when needed    Denim    Dark gray
# 1                                        Medium iron    Denim  Solid-color
# 2                                           Line dry    Denim  Solid-color
# 3                                 Can be dry cleaned    Denim  Solid-color
# 4                                  Machine wash cold    Denim  Solid-color
# 5                              Wash with like colors    Denim  Solid-color
# 6  The color of this denim may transfer onto ligh...    Denim  Solid-color
#
#   Imported Concept         Nice to know More sustainable materials color_name
# 0      Yes   DENIM  environmentalMarker        Recycled cotton 20%  Dark gray
# 1      Yes   DENIM  environmentalMarker        Recycled cotton 20%  Dark gray
# 2      Yes   DENIM  environmentalMarker        Recycled cotton 20%  Dark gray
# 3      Yes   DENIM  environmentalMarker        Recycled cotton 20%  Dark gray
# 4      Yes   DENIM  environmentalMarker        Recycled cotton 20%  Dark gray
# 5      Yes   DENIM  environmentalMarker        Recycled cotton 20%  Dark gray
# 6      Yes   DENIM  environmentalMarker        Recycled cotton 20%  Dark gray
#                Composition Size    Art. No.         Fit  \
# 0   Cotton 99%, Spandex 1%  NaN  0985159004  Skinny fit
# 1              Cotton 100%  NaN  0985159004  Skinny fit
# 2              Cotton 100%  NaN  0985159004  Skinny fit
# 3              Cotton 100%  NaN  0985159004  Skinny fit
# 4              Cotton 100%  NaN  0985159004  Skinny fit
# 5              Cotton 100%  NaN  0985159004  Skinny fit
# 6              Cotton 100%  NaN  0985159004  Skinny fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
#
#                       Care instructions Material       Description Imported  \
# 0  Only non-chlorine bleach when needed    Denim  Light denim blue      Yes
# 1                     Tumble dry medium    Denim       Solid-color      Yes
# 2                           Medium iron    Denim       Solid-color      Yes
# 3                     Machine wash cool    Denim       Solid-color      Yes
# 4                              Line dry    Denim       Solid-color      Yes
# 5                    Can be dry cleaned    Denim       Solid-color      Yes
# 6                 Wash with like colors    Denim       Solid-color      Yes
#
#   Concept         Nice to know More sustainable materials        color_name
# 0   DENIM  environmentalMarker        Recycled cotton 20%  Light denim blue
# 1   DENIM  environmentalMarker        Recycled cotton 20%  Light denim blue
# 2   DENIM  environmentalMarker        Recycled cotton 20%  Light denim blue
# 3   DENIM  environmentalMarker        Recycled cotton 20%  Light denim blue
# 4   DENIM  environmentalMarker        Recycled cotton 20%  Light denim blue
# 5   DENIM  environmentalMarker        Recycled cotton 20%  Light denim blue
# 6   DENIM  environmentalMarker        Recycled cotton 20%  Light denim blue
#                Composition Size    Art. No.         Fit  \
# 0   Cotton 99%, Spandex 1%  NaN  0985159005  Skinny fit
# 1              Cotton 100%  NaN  0985159005  Skinny fit
# 2              Cotton 100%  NaN  0985159005  Skinny fit
# 3              Cotton 100%  NaN  0985159005  Skinny fit
# 4              Cotton 100%  NaN  0985159005  Skinny fit
# 5              Cotton 100%  NaN  0985159005  Skinny fit
# 6              Cotton 100%  NaN  0985159005  Skinny fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
#
#                                    Care instructions Material  Description  \
# 0               Only non-chlorine bleach when needed    Denim    Dark blue
# 1                                        Medium iron    Denim  Solid-color
# 2                                           Line dry    Denim  Solid-color
# 3                                 Can be dry cleaned    Denim  Solid-color
# 4                                  Machine wash cold    Denim  Solid-color
# 5                              Wash with like colors    Denim  Solid-color
# 6  The color of this denim may transfer onto ligh...    Denim  Solid-color
#
#   Imported Concept         Nice to know More sustainable materials color_name
# 0      Yes   DENIM  environmentalMarker        Recycled cotton 20%  Dark blue
# 1      Yes   DENIM  environmentalMarker        Recycled cotton 20%  Dark blue
# 2      Yes   DENIM  environmentalMarker        Recycled cotton 20%  Dark blue
# 3      Yes   DENIM  environmentalMarker        Recycled cotton 20%  Dark blue
# 4      Yes   DENIM  environmentalMarker        Recycled cotton 20%  Dark blue
# 5      Yes   DENIM  environmentalMarker        Recycled cotton 20%  Dark blue
# 6      Yes   DENIM  environmentalMarker        Recycled cotton 20%  Dark blue
#                   Composition Size    Art. No.         Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  0985159006  Skinny fit
# 1   Polyester 65%, Cotton 35%  NaN  0985159006  Skinny fit
# 2   Polyester 65%, Cotton 35%  NaN  0985159006  Skinny fit
# 3   Polyester 65%, Cotton 35%  NaN  0985159006  Skinny fit
# 4   Polyester 65%, Cotton 35%  NaN  0985159006  Skinny fit
# 5   Polyester 65%, Cotton 35%  NaN  0985159006  Skinny fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
#
#                       Care instructions Material      Description Imported  \
# 0                     Tumble dry medium    Denim  Dark denim blue      Yes
# 1  Only non-chlorine bleach when needed    Denim      Solid-color      Yes
# 2                           Medium iron    Denim      Solid-color      Yes
# 3                     Machine wash cool    Denim      Solid-color      Yes
# 4                 Wash with like colors    Denim      Solid-color      Yes
# 5                    Can be dry cleaned    Denim      Solid-color      Yes
#
#   Concept         Nice to know More sustainable materials       color_name
# 0   DENIM  environmentalMarker        Recycled cotton 20%  Dark denim blue
# 1   DENIM  environmentalMarker        Recycled cotton 20%  Dark denim blue
# 2   DENIM  environmentalMarker        Recycled cotton 20%  Dark denim blue
# 3   DENIM  environmentalMarker        Recycled cotton 20%  Dark denim blue
# 4   DENIM  environmentalMarker        Recycled cotton 20%  Dark denim blue
# 5   DENIM  environmentalMarker        Recycled cotton 20%  Dark denim blue
#                   Composition Size    Art. No.         Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  0985159007  Skinny fit
# 1   Polyester 65%, Cotton 35%  NaN  0985159007  Skinny fit
# 2   Polyester 65%, Cotton 35%  NaN  0985159007  Skinny fit
# 3   Polyester 65%, Cotton 35%  NaN  0985159007  Skinny fit
# 4   Polyester 65%, Cotton 35%  NaN  0985159007  Skinny fit
# 5   Polyester 65%, Cotton 35%  NaN  0985159007  Skinny fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
#
#                       Care instructions Material  Description Imported  \
# 0                     Tumble dry medium    Denim   Denim blue      Yes
# 1  Only non-chlorine bleach when needed    Denim  Solid-color      Yes
# 2                           Medium iron    Denim  Solid-color      Yes
# 3                     Machine wash cool    Denim  Solid-color      Yes
# 4                 Wash with like colors    Denim  Solid-color      Yes
# 5                    Can be dry cleaned    Denim  Solid-color      Yes
#
#   Concept         Nice to know  color_name
# 0   DENIM  environmentalMarker  Denim blue
# 1   DENIM  environmentalMarker  Denim blue
# 2   DENIM  environmentalMarker  Denim blue
# 3   DENIM  environmentalMarker  Denim blue
# 4   DENIM  environmentalMarker  Denim blue
# 5   DENIM  environmentalMarker  Denim blue
#                   Composition Size    Art. No.         Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  0985159008  Skinny fit
# 1   Polyester 65%, Cotton 35%  NaN  0985159008  Skinny fit
# 2   Polyester 65%, Cotton 35%  NaN  0985159008  Skinny fit
# 3   Polyester 65%, Cotton 35%  NaN  0985159008  Skinny fit
# 4   Polyester 65%, Cotton 35%  NaN  0985159008  Skinny fit
# 5   Polyester 65%, Cotton 35%  NaN  0985159008  Skinny fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
#
#                       Care instructions Material  Description Imported  \
# 0                     Tumble dry medium    Denim    Dark gray      Yes
# 1  Only non-chlorine bleach when needed    Denim  Solid-color      Yes
# 2                           Medium iron    Denim  Solid-color      Yes
# 3                     Machine wash cool    Denim  Solid-color      Yes
# 4                 Wash with like colors    Denim  Solid-color      Yes
# 5                    Can be dry cleaned    Denim  Solid-color      Yes
#
#   Concept         Nice to know color_name
# 0   DENIM  environmentalMarker  Dark gray
# 1   DENIM  environmentalMarker  Dark gray
# 2   DENIM  environmentalMarker  Dark gray
# 3   DENIM  environmentalMarker  Dark gray
# 4   DENIM  environmentalMarker  Dark gray
# 5   DENIM  environmentalMarker  Dark gray
#                   Composition Size    Art. No.       Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  1024256001  Slim fit
# 1   Polyester 65%, Cotton 35%  NaN  1024256001  Slim fit
# 2   Polyester 65%, Cotton 35%  NaN  1024256001  Slim fit
# 3   Polyester 65%, Cotton 35%  NaN  1024256001  Slim fit
# 4   Polyester 65%, Cotton 35%  NaN  1024256001  Slim fit
# 5   Polyester 65%, Cotton 35%  NaN  1024256001  Slim fit
# 6   Polyester 65%, Cotton 35%  NaN  1024256001  Slim fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
#
#                                    Care instructions Material  Description  \
# 0               Only non-chlorine bleach when needed    Denim        Black
# 1                                        Medium iron    Denim  Solid-color
# 2                                           Line dry    Denim  Solid-color
# 3                                 Can be dry cleaned    Denim  Solid-color
# 4                                  Machine wash cold    Denim  Solid-color
# 5                              Wash with like colors    Denim  Solid-color
# 6  The color of this denim may transfer onto ligh...    Denim  Solid-color
#
#   Imported Concept         Nice to know color_name
# 0      Yes   DENIM  environmentalMarker      Black
# 1      Yes   DENIM  environmentalMarker      Black
# 2      Yes   DENIM  environmentalMarker      Black
# 3      Yes   DENIM  environmentalMarker      Black
# 4      Yes   DENIM  environmentalMarker      Black
# 5      Yes   DENIM  environmentalMarker      Black
# 6      Yes   DENIM  environmentalMarker      Black
#                   Composition Size    Art. No.       Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  1024256002  Slim fit
# 1   Polyester 65%, Cotton 35%  NaN  1024256002  Slim fit
# 2   Polyester 65%, Cotton 35%  NaN  1024256002  Slim fit
# 3   Polyester 65%, Cotton 35%  NaN  1024256002  Slim fit
# 4   Polyester 65%, Cotton 35%  NaN  1024256002  Slim fit
# 5   Polyester 65%, Cotton 35%  NaN  1024256002  Slim fit
# 6   Polyester 65%, Cotton 35%  NaN  1024256002  Slim fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
#
#                                    Care instructions Material  \
# 0               Only non-chlorine bleach when needed    Denim
# 1                                        Medium iron    Denim
# 2                                           Line dry    Denim
# 3                                 Can be dry cleaned    Denim
# 4                                  Machine wash cold    Denim
# 5                              Wash with like colors    Denim
# 6  The color of this denim may transfer onto ligh...    Denim
#
#         Description Imported Concept         Nice to know        color_name
# 0  Light denim blue      Yes   DENIM  environmentalMarker  Light denim blue
# 1       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 2       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 3       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 4       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 5       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 6       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
#                   Composition Size    Art. No.       Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  1024256003  Slim fit
# 1   Polyester 65%, Cotton 35%  NaN  1024256003  Slim fit
# 2   Polyester 65%, Cotton 35%  NaN  1024256003  Slim fit
# 3   Polyester 65%, Cotton 35%  NaN  1024256003  Slim fit
# 4   Polyester 65%, Cotton 35%  NaN  1024256003  Slim fit
# 5   Polyester 65%, Cotton 35%  NaN  1024256003  Slim fit
# 6   Polyester 65%, Cotton 35%  NaN  1024256003  Slim fit
# 7   Polyester 65%, Cotton 35%  NaN  1024256003  Slim fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
# 7                   Long      Regular waist
#
#                                    Care instructions Material  \
# 0               Only non-chlorine bleach when needed    Denim
# 1                                        Medium iron    Denim
# 2                                  Machine wash cool    Denim
# 3                                           Line dry    Denim
# 4                                 Can be dry cleaned    Denim
# 5                                  Machine wash cold    Denim
# 6                              Wash with like colors    Denim
# 7  The color of this denim may transfer onto ligh...    Denim
#
#         Description Imported Concept         Nice to know        color_name
# 0  Light denim blue      Yes   DENIM  environmentalMarker  Light denim blue
# 1       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 2       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 3       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 4       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 5       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 6       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 7       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
#                   Composition Size    Art. No.       Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  1024256004  Slim fit
# 1   Polyester 65%, Cotton 35%  NaN  1024256004  Slim fit
# 2   Polyester 65%, Cotton 35%  NaN  1024256004  Slim fit
# 3   Polyester 65%, Cotton 35%  NaN  1024256004  Slim fit
# 4   Polyester 65%, Cotton 35%  NaN  1024256004  Slim fit
# 5   Polyester 65%, Cotton 35%  NaN  1024256004  Slim fit
# 6   Polyester 65%, Cotton 35%  NaN  1024256004  Slim fit
# 7   Polyester 65%, Cotton 35%  NaN  1024256004  Slim fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
# 7                   Long      Regular waist
#
#                                    Care instructions Material  Description  \
# 0               Only non-chlorine bleach when needed    Denim   Denim blue
# 1                                        Medium iron    Denim  Solid-color
# 2                                  Machine wash cool    Denim  Solid-color
# 3                                           Line dry    Denim  Solid-color
# 4                                 Can be dry cleaned    Denim  Solid-color
# 5                                  Machine wash cold    Denim  Solid-color
# 6                              Wash with like colors    Denim  Solid-color
# 7  The color of this denim may transfer onto ligh...    Denim  Solid-color
#
#   Imported Concept         Nice to know  color_name
# 0      Yes   DENIM  environmentalMarker  Denim blue
# 1      Yes   DENIM  environmentalMarker  Denim blue
# 2      Yes   DENIM  environmentalMarker  Denim blue
# 3      Yes   DENIM  environmentalMarker  Denim blue
# 4      Yes   DENIM  environmentalMarker  Denim blue
# 5      Yes   DENIM  environmentalMarker  Denim blue
# 6      Yes   DENIM  environmentalMarker  Denim blue
# 7      Yes   DENIM  environmentalMarker  Denim blue
#                   Composition Size    Art. No.       Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  1024256005  Slim fit
# 1   Polyester 65%, Cotton 35%  NaN  1024256005  Slim fit
# 2   Polyester 65%, Cotton 35%  NaN  1024256005  Slim fit
# 3   Polyester 65%, Cotton 35%  NaN  1024256005  Slim fit
# 4   Polyester 65%, Cotton 35%  NaN  1024256005  Slim fit
# 5   Polyester 65%, Cotton 35%  NaN  1024256005  Slim fit
# 6   Polyester 65%, Cotton 35%  NaN  1024256005  Slim fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
#
#                                    Care instructions Material  Description  \
# 0               Only non-chlorine bleach when needed    Denim    Dark blue
# 1                                        Medium iron    Denim  Solid-color
# 2                                           Line dry    Denim  Solid-color
# 3                                 Can be dry cleaned    Denim  Solid-color
# 4                                  Machine wash cold    Denim  Solid-color
# 5                              Wash with like colors    Denim  Solid-color
# 6  The color of this denim may transfer onto ligh...    Denim  Solid-color
#
#   Imported Concept         Nice to know color_name
# 0      Yes   DENIM  environmentalMarker  Dark blue
# 1      Yes   DENIM  environmentalMarker  Dark blue
# 2      Yes   DENIM  environmentalMarker  Dark blue
# 3      Yes   DENIM  environmentalMarker  Dark blue
# 4      Yes   DENIM  environmentalMarker  Dark blue
# 5      Yes   DENIM  environmentalMarker  Dark blue
# 6      Yes   DENIM  environmentalMarker  Dark blue
#                Composition Size    Art. No.       Fit messages.garmentLength  \
# 0   Cotton 99%, Spandex 1%  NaN  1024256006  Slim fit                   Long
# 1              Cotton 100%  NaN  1024256006  Slim fit                   Long
# 2              Cotton 100%  NaN  1024256006  Slim fit                   Long
# 3              Cotton 100%  NaN  1024256006  Slim fit                   Long
# 4              Cotton 100%  NaN  1024256006  Slim fit                   Long
# 5              Cotton 100%  NaN  1024256006  Slim fit                   Long
# 6              Cotton 100%  NaN  1024256006  Slim fit                   Long
#
#   messages.waistRise                                  Care instructions  \
# 0      Regular waist               Only non-chlorine bleach when needed
# 1      Regular waist                                        Medium iron
# 2      Regular waist                                           Line dry
# 3      Regular waist                                 Can be dry cleaned
# 4      Regular waist                                  Machine wash cold
# 5      Regular waist                              Wash with like colors
# 6      Regular waist  The color of this denim may transfer onto ligh...
#
#   Material      Description Imported Concept         Nice to know  \
# 0    Denim  Dark denim blue      Yes   DENIM  environmentalMarker
# 1    Denim      Solid-color      Yes   DENIM  environmentalMarker
# 2    Denim      Solid-color      Yes   DENIM  environmentalMarker
# 3    Denim      Solid-color      Yes   DENIM  environmentalMarker
# 4    Denim      Solid-color      Yes   DENIM  environmentalMarker
# 5    Denim      Solid-color      Yes   DENIM  environmentalMarker
# 6    Denim      Solid-color      Yes   DENIM  environmentalMarker
#
#         color_name
# 0  Dark denim blue
# 1  Dark denim blue
# 2  Dark denim blue
# 3  Dark denim blue
# 4  Dark denim blue
# 5  Dark denim blue
# 6  Dark denim blue
#                   Composition Size    Art. No.       Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  1024256007  Slim fit
# 1   Polyester 65%, Cotton 35%  NaN  1024256007  Slim fit
# 2   Polyester 65%, Cotton 35%  NaN  1024256007  Slim fit
# 3   Polyester 65%, Cotton 35%  NaN  1024256007  Slim fit
# 4   Polyester 65%, Cotton 35%  NaN  1024256007  Slim fit
# 5   Polyester 65%, Cotton 35%  NaN  1024256007  Slim fit
# 6   Polyester 65%, Cotton 35%  NaN  1024256007  Slim fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
#
#                                    Care instructions Material  Description  \
# 0               Only non-chlorine bleach when needed    Denim    Dark gray
# 1                                        Medium iron    Denim  Solid-color
# 2                                           Line dry    Denim  Solid-color
# 3                                 Can be dry cleaned    Denim  Solid-color
# 4                                  Machine wash cold    Denim  Solid-color
# 5                              Wash with like colors    Denim  Solid-color
# 6  The color of this denim may transfer onto ligh...    Denim  Solid-color
#
#   Imported Concept         Nice to know color_name
# 0      Yes   DENIM  environmentalMarker  Dark gray
# 1      Yes   DENIM  environmentalMarker  Dark gray
# 2      Yes   DENIM  environmentalMarker  Dark gray
# 3      Yes   DENIM  environmentalMarker  Dark gray
# 4      Yes   DENIM  environmentalMarker  Dark gray
# 5      Yes   DENIM  environmentalMarker  Dark gray
# 6      Yes   DENIM  environmentalMarker  Dark gray
#                Composition Size    Art. No.       Fit messages.garmentLength  \
# 0   Cotton 99%, Spandex 1%  NaN  1024256008  Slim fit                   Long
# 1              Cotton 100%  NaN  1024256008  Slim fit                   Long
# 2              Cotton 100%  NaN  1024256008  Slim fit                   Long
# 3              Cotton 100%  NaN  1024256008  Slim fit                   Long
# 4              Cotton 100%  NaN  1024256008  Slim fit                   Long
# 5              Cotton 100%  NaN  1024256008  Slim fit                   Long
# 6              Cotton 100%  NaN  1024256008  Slim fit                   Long
#
#   messages.waistRise                                  Care instructions  \
# 0      Regular waist               Only non-chlorine bleach when needed
# 1      Regular waist                                  Tumble dry medium
# 2      Regular waist                                  Machine wash cool
# 3      Regular waist                                 Can be dry cleaned
# 4      Regular waist                              Wash with like colors
# 5      Regular waist                                          High iron
# 6      Regular waist  The color of this denim may transfer onto ligh...
#
#   Material  Description Imported Concept         Nice to know color_name
# 0    Denim        White      Yes   DENIM  environmentalMarker      White
# 1    Denim  Solid-color      Yes   DENIM  environmentalMarker      White
# 2    Denim  Solid-color      Yes   DENIM  environmentalMarker      White
# 3    Denim  Solid-color      Yes   DENIM  environmentalMarker      White
# 4    Denim  Solid-color      Yes   DENIM  environmentalMarker      White
# 5    Denim  Solid-color      Yes   DENIM  environmentalMarker      White
# 6    Denim  Solid-color      Yes   DENIM  environmentalMarker      White
#                                     Composition Size    Art. No.       Fit  \
# 0   Cotton 90%, Elastomultiester 8%, Spandex 2%  NaN  1008110002  Slim fit
# 1                                   Cotton 100%  NaN  1008110002  Slim fit
# 2                                   Cotton 100%  NaN  1008110002  Slim fit
# 3                                   Cotton 100%  NaN  1008110002  Slim fit
# 4                                   Cotton 100%  NaN  1008110002  Slim fit
# 5                                   Cotton 100%  NaN  1008110002  Slim fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
#
#                       Care instructions Material  Description Imported  \
# 0                     Tumble dry medium    Denim        Black      Yes
# 1  Only non-chlorine bleach when needed    Denim  Solid-color      Yes
# 2                           Medium iron    Denim  Solid-color      Yes
# 3                     Machine wash cool    Denim  Solid-color      Yes
# 4                 Wash with like colors    Denim  Solid-color      Yes
# 5                    Can be dry cleaned    Denim  Solid-color      Yes
#
#   Concept         Nice to know           color_name
# 0   DENIM  environmentalMarker  Black/No fade black
# 1   DENIM  environmentalMarker  Black/No fade black
# 2   DENIM  environmentalMarker  Black/No fade black
# 3   DENIM  environmentalMarker  Black/No fade black
# 4   DENIM  environmentalMarker  Black/No fade black
# 5   DENIM  environmentalMarker  Black/No fade black
#                                     Composition Size    Art. No.       Fit  \
# 0   Cotton 90%, Elastomultiester 8%, Spandex 2%  NaN  1008110001  Slim fit
# 1                     Polyester 80%, Cotton 20%  NaN  1008110001  Slim fit
# 2                     Polyester 80%, Cotton 20%  NaN  1008110001  Slim fit
# 3                     Polyester 80%, Cotton 20%  NaN  1008110001  Slim fit
# 4                     Polyester 80%, Cotton 20%  NaN  1008110001  Slim fit
# 5                     Polyester 80%, Cotton 20%  NaN  1008110001  Slim fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
#
#                       Care instructions Material      Description Imported  \
# 0                     Tumble dry medium    Denim  Dark denim blue      Yes
# 1  Only non-chlorine bleach when needed    Denim      Solid-color      Yes
# 2                           Medium iron    Denim      Solid-color      Yes
# 3                     Machine wash cool    Denim      Solid-color      Yes
# 4                 Wash with like colors    Denim      Solid-color      Yes
# 5                    Can be dry cleaned    Denim      Solid-color      Yes
#
#   Concept         Nice to know       color_name
# 0   DENIM  environmentalMarker  Dark denim blue
# 1   DENIM  environmentalMarker  Dark denim blue
# 2   DENIM  environmentalMarker  Dark denim blue
# 3   DENIM  environmentalMarker  Dark denim blue
# 4   DENIM  environmentalMarker  Dark denim blue
# 5   DENIM  environmentalMarker  Dark denim blue
#                                     Composition Size    Art. No.       Fit  \
# 0   Cotton 89%, Elastomultiester 9%, Spandex 2%  NaN  1008110003  Slim fit
# 1                     Polyester 80%, Cotton 20%  NaN  1008110003  Slim fit
# 2                     Polyester 80%, Cotton 20%  NaN  1008110003  Slim fit
# 3                     Polyester 80%, Cotton 20%  NaN  1008110003  Slim fit
# 4                     Polyester 80%, Cotton 20%  NaN  1008110003  Slim fit
# 5                     Polyester 80%, Cotton 20%  NaN  1008110003  Slim fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
#
#                       Care instructions Material       Description Imported  \
# 0                     Tumble dry medium    Denim  Light denim blue      Yes
# 1  Only non-chlorine bleach when needed    Denim       Solid-color      Yes
# 2                           Medium iron    Denim       Solid-color      Yes
# 3                     Machine wash cool    Denim       Solid-color      Yes
# 4                 Wash with like colors    Denim       Solid-color      Yes
# 5                    Can be dry cleaned    Denim       Solid-color      Yes
#
#   Concept         Nice to know        color_name
# 0   DENIM  environmentalMarker  Light denim blue
# 1   DENIM  environmentalMarker  Light denim blue
# 2   DENIM  environmentalMarker  Light denim blue
# 3   DENIM  environmentalMarker  Light denim blue
# 4   DENIM  environmentalMarker  Light denim blue
# 5   DENIM  environmentalMarker  Light denim blue
#                                     Composition Size    Art. No.       Fit  \
# 0   Cotton 89%, Elastomultiester 9%, Spandex 2%  NaN  1008110005  Slim fit
# 1                     Polyester 80%, Cotton 20%  NaN  1008110005  Slim fit
# 2                     Polyester 80%, Cotton 20%  NaN  1008110005  Slim fit
# 3                     Polyester 80%, Cotton 20%  NaN  1008110005  Slim fit
# 4                     Polyester 80%, Cotton 20%  NaN  1008110005  Slim fit
# 5                     Polyester 80%, Cotton 20%  NaN  1008110005  Slim fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
#
#                       Care instructions Material       Description Imported  \
# 0                     Tumble dry medium    Denim  Light denim blue      Yes
# 1  Only non-chlorine bleach when needed    Denim       Solid-color      Yes
# 2                           Medium iron    Denim       Solid-color      Yes
# 3                     Machine wash cool    Denim       Solid-color      Yes
# 4                 Wash with like colors    Denim       Solid-color      Yes
# 5                    Can be dry cleaned    Denim       Solid-color      Yes
#
#   Concept         Nice to know        color_name
# 0   DENIM  environmentalMarker  Light denim blue
# 1   DENIM  environmentalMarker  Light denim blue
# 2   DENIM  environmentalMarker  Light denim blue
# 3   DENIM  environmentalMarker  Light denim blue
# 4   DENIM  environmentalMarker  Light denim blue
# 5   DENIM  environmentalMarker  Light denim blue
#                                     Composition Size    Art. No.       Fit  \
# 0   Cotton 89%, Elastomultiester 9%, Spandex 2%  NaN  1008110006  Slim fit
# 1                     Polyester 80%, Cotton 20%  NaN  1008110006  Slim fit
# 2                     Polyester 80%, Cotton 20%  NaN  1008110006  Slim fit
# 3                     Polyester 80%, Cotton 20%  NaN  1008110006  Slim fit
# 4                     Polyester 80%, Cotton 20%  NaN  1008110006  Slim fit
# 5                     Polyester 80%, Cotton 20%  NaN  1008110006  Slim fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
#
#                       Care instructions Material Description Imported Concept  \
# 0                     Tumble dry medium    Denim  Denim blue      Yes   DENIM
# 1  Only non-chlorine bleach when needed    Denim  Denim blue      Yes   DENIM
# 2                           Medium iron    Denim  Denim blue      Yes   DENIM
# 3                     Machine wash cool    Denim  Denim blue      Yes   DENIM
# 4                 Wash with like colors    Denim  Denim blue      Yes   DENIM
# 5                    Can be dry cleaned    Denim  Denim blue      Yes   DENIM
#
#           Nice to know  color_name
# 0  environmentalMarker  Denim blue
# 1  environmentalMarker  Denim blue
# 2  environmentalMarker  Denim blue
# 3  environmentalMarker  Denim blue
# 4  environmentalMarker  Denim blue
# 5  environmentalMarker  Denim blue
#                   Composition Size    Art. No.       Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  1024256003  Slim fit
# 1   Polyester 65%, Cotton 35%  NaN  1024256003  Slim fit
# 2   Polyester 65%, Cotton 35%  NaN  1024256003  Slim fit
# 3   Polyester 65%, Cotton 35%  NaN  1024256003  Slim fit
# 4   Polyester 65%, Cotton 35%  NaN  1024256003  Slim fit
# 5   Polyester 65%, Cotton 35%  NaN  1024256003  Slim fit
# 6   Polyester 65%, Cotton 35%  NaN  1024256003  Slim fit
# 7   Polyester 65%, Cotton 35%  NaN  1024256003  Slim fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
# 7                   Long      Regular waist
#
#                                    Care instructions Material  \
# 0               Only non-chlorine bleach when needed    Denim
# 1                                        Medium iron    Denim
# 2                                  Machine wash cool    Denim
# 3                                           Line dry    Denim
# 4                                 Can be dry cleaned    Denim
# 5                                  Machine wash cold    Denim
# 6                              Wash with like colors    Denim
# 7  The color of this denim may transfer onto ligh...    Denim
#
#         Description Imported Concept         Nice to know        color_name
# 0  Light denim blue      Yes   DENIM  environmentalMarker  Light denim blue
# 1       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 2       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 3       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 4       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 5       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 6       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 7       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
#                   Composition Size    Art. No.       Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  1024256001  Slim fit
# 1   Polyester 65%, Cotton 35%  NaN  1024256001  Slim fit
# 2   Polyester 65%, Cotton 35%  NaN  1024256001  Slim fit
# 3   Polyester 65%, Cotton 35%  NaN  1024256001  Slim fit
# 4   Polyester 65%, Cotton 35%  NaN  1024256001  Slim fit
# 5   Polyester 65%, Cotton 35%  NaN  1024256001  Slim fit
# 6   Polyester 65%, Cotton 35%  NaN  1024256001  Slim fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
#
#                                    Care instructions Material  Description  \
# 0               Only non-chlorine bleach when needed    Denim        Black
# 1                                        Medium iron    Denim  Solid-color
# 2                                           Line dry    Denim  Solid-color
# 3                                 Can be dry cleaned    Denim  Solid-color
# 4                                  Machine wash cold    Denim  Solid-color
# 5                              Wash with like colors    Denim  Solid-color
# 6  The color of this denim may transfer onto ligh...    Denim  Solid-color
#
#   Imported Concept         Nice to know color_name
# 0      Yes   DENIM  environmentalMarker      Black
# 1      Yes   DENIM  environmentalMarker      Black
# 2      Yes   DENIM  environmentalMarker      Black
# 3      Yes   DENIM  environmentalMarker      Black
# 4      Yes   DENIM  environmentalMarker      Black
# 5      Yes   DENIM  environmentalMarker      Black
# 6      Yes   DENIM  environmentalMarker      Black
#                   Composition Size    Art. No.       Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  1024256002  Slim fit
# 1   Polyester 65%, Cotton 35%  NaN  1024256002  Slim fit
# 2   Polyester 65%, Cotton 35%  NaN  1024256002  Slim fit
# 3   Polyester 65%, Cotton 35%  NaN  1024256002  Slim fit
# 4   Polyester 65%, Cotton 35%  NaN  1024256002  Slim fit
# 5   Polyester 65%, Cotton 35%  NaN  1024256002  Slim fit
# 6   Polyester 65%, Cotton 35%  NaN  1024256002  Slim fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
#
#                                    Care instructions Material  \
# 0               Only non-chlorine bleach when needed    Denim
# 1                                        Medium iron    Denim
# 2                                           Line dry    Denim
# 3                                 Can be dry cleaned    Denim
# 4                                  Machine wash cold    Denim
# 5                              Wash with like colors    Denim
# 6  The color of this denim may transfer onto ligh...    Denim
#
#         Description Imported Concept         Nice to know        color_name
# 0  Light denim blue      Yes   DENIM  environmentalMarker  Light denim blue
# 1       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 2       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 3       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 4       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 5       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 6       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
#                   Composition Size    Art. No.       Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  1024256004  Slim fit
# 1   Polyester 65%, Cotton 35%  NaN  1024256004  Slim fit
# 2   Polyester 65%, Cotton 35%  NaN  1024256004  Slim fit
# 3   Polyester 65%, Cotton 35%  NaN  1024256004  Slim fit
# 4   Polyester 65%, Cotton 35%  NaN  1024256004  Slim fit
# 5   Polyester 65%, Cotton 35%  NaN  1024256004  Slim fit
# 6   Polyester 65%, Cotton 35%  NaN  1024256004  Slim fit
# 7   Polyester 65%, Cotton 35%  NaN  1024256004  Slim fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
# 7                   Long      Regular waist
#
#                                    Care instructions Material  Description  \
# 0               Only non-chlorine bleach when needed    Denim   Denim blue
# 1                                        Medium iron    Denim  Solid-color
# 2                                  Machine wash cool    Denim  Solid-color
# 3                                           Line dry    Denim  Solid-color
# 4                                 Can be dry cleaned    Denim  Solid-color
# 5                                  Machine wash cold    Denim  Solid-color
# 6                              Wash with like colors    Denim  Solid-color
# 7  The color of this denim may transfer onto ligh...    Denim  Solid-color
#
#   Imported Concept         Nice to know  color_name
# 0      Yes   DENIM  environmentalMarker  Denim blue
# ...
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
#
#                                    Care instructions      Material  \
# 0               Only non-chlorine bleach when needed  keyFibreType
# 1                                  Tumble dry medium         Denim
# 2                                        Medium iron         Denim
# 3                                 Can be dry cleaned         Denim
# 4                                  Machine wash cold         Denim
# 5                              Wash with like colors         Denim
# 6  The color of this denim may transfer onto ligh...         Denim
#
#         Description Imported Concept         Nice to know        color_name
# 0  Light denim blue      Yes   DENIM  environmentalMarker  Light denim blue
# 1       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 2       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 3       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 4       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 5       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 6       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
#                   Composition Size    Art. No.          Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  1008549008  Regular fit
# 1   Polyester 65%, Cotton 35%  NaN  1008549008  Regular fit
# 2   Polyester 65%, Cotton 35%  NaN  1008549008  Regular fit
# 3   Polyester 65%, Cotton 35%  NaN  1008549008  Regular fit
# 4   Polyester 65%, Cotton 35%  NaN  1008549008  Regular fit
# 5   Polyester 65%, Cotton 35%  NaN  1008549008  Regular fit
# 6   Polyester 65%, Cotton 35%  NaN  1008549008  Regular fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
#
#                                    Care instructions      Material  \
# 0               Only non-chlorine bleach when needed  keyFibreType
# 1                                  Tumble dry medium         Denim
# 2                                        Medium iron         Denim
# 3                                 Can be dry cleaned         Denim
# 4                                  Machine wash cold         Denim
# 5                              Wash with like colors         Denim
# 6  The color of this denim may transfer onto ligh...         Denim
#
#         Description Imported Concept         Nice to know        color_name
# 0  Light denim blue      Yes   DENIM  environmentalMarker  Light denim blue
# 1       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 2       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 3       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 4       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 5       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
# 6       Solid-color      Yes   DENIM  environmentalMarker  Light denim blue
#                   Composition Size    Art. No.          Fit  \
# 0      Cotton 98%, Spandex 2%  NaN  1008549001  Regular fit
# 1   Polyester 65%, Cotton 35%  NaN  1008549001  Regular fit
# 2   Polyester 65%, Cotton 35%  NaN  1008549001  Regular fit
# 3   Polyester 65%, Cotton 35%  NaN  1008549001  Regular fit
# 4   Polyester 65%, Cotton 35%  NaN  1008549001  Regular fit
# 5   Polyester 65%, Cotton 35%  NaN  1008549001  Regular fit
# 6   Polyester 65%, Cotton 35%  NaN  1008549001  Regular fit
# 7   Polyester 65%, Cotton 35%  NaN  1008549001  Regular fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
# 7                   Long      Regular waist
#
#                                    Care instructions      Material  \
# 0               Only non-chlorine bleach when needed  keyFibreType
# 1                                        Medium iron         Denim
# 2                                  Machine wash cool         Denim
# 3                                           Line dry         Denim
# 4                                 Can be dry cleaned         Denim
# 5                                  Machine wash cold         Denim
# 6                              Wash with like colors         Denim
# 7  The color of this denim may transfer onto ligh...         Denim
#
#         Description Imported Concept         Nice to know  \
# 0  Light denim blue      Yes   DENIM  environmentalMarker
# 1       Solid-color      Yes   DENIM  environmentalMarker
# 2       Solid-color      Yes   DENIM  environmentalMarker
# 3       Solid-color      Yes   DENIM  environmentalMarker
# 4       Solid-color      Yes   DENIM  environmentalMarker
# 5       Solid-color      Yes   DENIM  environmentalMarker
# 6       Solid-color      Yes   DENIM  environmentalMarker
# 7       Solid-color      Yes   DENIM  environmentalMarker
#
#   More sustainable materials        color_name
# 0        Recycled cotton 20%  Light denim blue
# 1        Recycled cotton 20%  Light denim blue
# 2        Recycled cotton 20%  Light denim blue
# 3        Recycled cotton 20%  Light denim blue
# 4        Recycled cotton 20%  Light denim blue
# 5        Recycled cotton 20%  Light denim blue
# 6        Recycled cotton 20%  Light denim blue
# 7        Recycled cotton 20%  Light denim blue
#                   Composition Size    Art. No.          Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  1008549002  Regular fit
# 1   Polyester 65%, Cotton 35%  NaN  1008549002  Regular fit
# 2   Polyester 65%, Cotton 35%  NaN  1008549002  Regular fit
# 3   Polyester 65%, Cotton 35%  NaN  1008549002  Regular fit
# 4   Polyester 65%, Cotton 35%  NaN  1008549002  Regular fit
# 5   Polyester 65%, Cotton 35%  NaN  1008549002  Regular fit
# 6   Polyester 65%, Cotton 35%  NaN  1008549002  Regular fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
#
#                                    Care instructions      Material  \
# 0               Only non-chlorine bleach when needed  keyFibreType
# 1                                        Medium iron         Denim
# 2                                           Line dry         Denim
# 3                                 Can be dry cleaned         Denim
# 4                                  Machine wash cold         Denim
# 5                              Wash with like colors         Denim
# 6  The color of this denim may transfer onto ligh...         Denim
#
#    Description Imported Concept         Nice to know  \
# 0   Denim blue      Yes   DENIM  environmentalMarker
# 1  Solid-color      Yes   DENIM  environmentalMarker
# 2  Solid-color      Yes   DENIM  environmentalMarker
# 3  Solid-color      Yes   DENIM  environmentalMarker
# 4  Solid-color      Yes   DENIM  environmentalMarker
# 5  Solid-color      Yes   DENIM  environmentalMarker
# 6  Solid-color      Yes   DENIM  environmentalMarker
#
#   More sustainable materials  color_name
# 0        Recycled cotton 20%  Denim blue
# 1        Recycled cotton 20%  Denim blue
# 2        Recycled cotton 20%  Denim blue
# 3        Recycled cotton 20%  Denim blue
# 4        Recycled cotton 20%  Denim blue
# 5        Recycled cotton 20%  Denim blue
# 6        Recycled cotton 20%  Denim blue
#                   Composition Size    Art. No.          Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  1008549003  Regular fit
# 1   Polyester 65%, Cotton 35%  NaN  1008549003  Regular fit
# 2   Polyester 65%, Cotton 35%  NaN  1008549003  Regular fit
# 3   Polyester 65%, Cotton 35%  NaN  1008549003  Regular fit
# 4   Polyester 65%, Cotton 35%  NaN  1008549003  Regular fit
# 5   Polyester 65%, Cotton 35%  NaN  1008549003  Regular fit
# 6   Polyester 65%, Cotton 35%  NaN  1008549003  Regular fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
#
#                       Care instructions      Material  Description Imported  \
# 0  Only non-chlorine bleach when needed  keyFibreType    Dark gray      Yes
# 1                     Tumble dry medium         Denim  Solid-color      Yes
# 2                           Medium iron         Denim  Solid-color      Yes
# 3                     Machine wash cool         Denim  Solid-color      Yes
# 4                              Line dry         Denim  Solid-color      Yes
# 5                    Can be dry cleaned         Denim  Solid-color      Yes
# 6                 Wash with like colors         Denim  Solid-color      Yes
#
#   Concept         Nice to know color_name
# 0   DENIM  environmentalMarker  Dark gray
# 1   DENIM  environmentalMarker  Dark gray
# 2   DENIM  environmentalMarker  Dark gray
# 3   DENIM  environmentalMarker  Dark gray
# 4   DENIM  environmentalMarker  Dark gray
# 5   DENIM  environmentalMarker  Dark gray
# 6   DENIM  environmentalMarker  Dark gray
#                   Composition Size    Art. No.          Fit  \
# 0      Cotton 99%, Spandex 1%  NaN  1008549004  Regular fit
# 1   Polyester 63%, Cotton 37%  NaN  1008549004  Regular fit
# 2   Polyester 63%, Cotton 37%  NaN  1008549004  Regular fit
# 3   Polyester 63%, Cotton 37%  NaN  1008549004  Regular fit
# 4   Polyester 63%, Cotton 37%  NaN  1008549004  Regular fit
# 5   Polyester 63%, Cotton 37%  NaN  1008549004  Regular fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
#
#                       Care instructions      Material  Description Imported  \
# 0                     Tumble dry medium  keyFibreType    Dark blue      Yes
# 1  Only non-chlorine bleach when needed         Denim  Solid-color      Yes
# 2                           Medium iron         Denim  Solid-color      Yes
# 3                     Machine wash cool         Denim  Solid-color      Yes
# 4                 Wash with like colors         Denim  Solid-color      Yes
# 5                    Can be dry cleaned         Denim  Solid-color      Yes
#
#   Concept         Nice to know More sustainable materials color_name
# 0   DENIM  environmentalMarker        Recycled cotton 20%  Dark blue
# 1   DENIM  environmentalMarker        Recycled cotton 20%  Dark blue
# 2   DENIM  environmentalMarker        Recycled cotton 20%  Dark blue
# 3   DENIM  environmentalMarker        Recycled cotton 20%  Dark blue
# 4   DENIM  environmentalMarker        Recycled cotton 20%  Dark blue
# 5   DENIM  environmentalMarker        Recycled cotton 20%  Dark blue
#                Composition Size    Art. No.          Fit  \
# 0   Cotton 99%, Spandex 1%  NaN  1008549006  Regular fit
# 1      Pocket: Cotton 100%  NaN  1008549006  Regular fit
# 2      Pocket: Cotton 100%  NaN  1008549006  Regular fit
# 3      Pocket: Cotton 100%  NaN  1008549006  Regular fit
# 4      Pocket: Cotton 100%  NaN  1008549006  Regular fit
# 5      Pocket: Cotton 100%  NaN  1008549006  Regular fit
# 6      Pocket: Cotton 100%  NaN  1008549006  Regular fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
# 6                   Long      Regular waist
#
#                                    Care instructions      Material  \
# 0               Only non-chlorine bleach when needed  keyFibreType
# 1                                        Medium iron         Denim
# 2                                           Line dry         Denim
# 3                                 Can be dry cleaned         Denim
# 4                                  Machine wash cold         Denim
# 5                              Wash with like colors         Denim
# 6  The color of this denim may transfer onto ligh...         Denim
#
#    Description Imported Concept         Nice to know  \
# 0        Black      Yes   DENIM  environmentalMarker
# 1  Solid-color      Yes   DENIM  environmentalMarker
# 2  Solid-color      Yes   DENIM  environmentalMarker
# 3  Solid-color      Yes   DENIM  environmentalMarker
# 4  Solid-color      Yes   DENIM  environmentalMarker
# 5  Solid-color      Yes   DENIM  environmentalMarker
# 6  Solid-color      Yes   DENIM  environmentalMarker
#
#   More sustainable materials color_name
# 0        Recycled cotton 20%      Black
# 1        Recycled cotton 20%      Black
# 2        Recycled cotton 20%      Black
# 3        Recycled cotton 20%      Black
# 4        Recycled cotton 20%      Black
# 5        Recycled cotton 20%      Black
# 6        Recycled cotton 20%      Black
#                Composition Size    Art. No.          Fit  \
# 0   Cotton 99%, Spandex 1%  NaN  1008549007  Regular fit
# 1      Pocket: Cotton 100%  NaN  1008549007  Regular fit
# 2      Pocket: Cotton 100%  NaN  1008549007  Regular fit
# 3      Pocket: Cotton 100%  NaN  1008549007  Regular fit
# 4      Pocket: Cotton 100%  NaN  1008549007  Regular fit
# 5      Pocket: Cotton 100%  NaN  1008549007  Regular fit
#
#   messages.garmentLength messages.waistRise  \
# 0                   Long      Regular waist
# 1                   Long      Regular waist
# 2                   Long      Regular waist
# 3                   Long      Regular waist
# 4                   Long      Regular waist
# 5                   Long      Regular waist
#
#                       Care instructions      Material  Description Imported  \
# 0  Only non-chlorine bleach when needed  keyFibreType   Light gray      Yes
# 1                           Medium iron         Denim  Solid-color      Yes
# 2                     Machine wash cool         Denim  Solid-color      Yes
# 3                 Wash with like colors         Denim  Solid-color      Yes
# 4                              Line dry         Denim  Solid-color      Yes
# 5                    Can be dry cleaned         Denim  Solid-color      Yes
#
#   Concept         Nice to know  color_name
# 0   DENIM  environmentalMarker  Light gray
# 1   DENIM  environmentalMarker  Light gray
# 2   DENIM  environmentalMarker  Light gray
# 3   DENIM  environmentalMarker  Light gray
# 4   DENIM  environmentalMarker  Light gray
# 5   DENIM  environmentalMarker  Light gray

# %%
# Out:
#     product_id              composition  color_name size          fit  \
# 0   1008549007   Cotton 99%, Spandex 1%  Light gray  NaN  Regular fit
# 1   1008549007      Pocket: Cotton 100%  Light gray  NaN  Regular fit
# 2   1008549007      Pocket: Cotton 100%  Light gray  NaN  Regular fit
# 3   1008549007      Pocket: Cotton 100%  Light gray  NaN  Regular fit
# 4   1008549007      Pocket: Cotton 100%  Light gray  NaN  Regular fit
# ..         ...                      ...         ...  ...          ...
# 2   0985159001              Cotton 100%       Black  NaN   Skinny fit
# 3   0985159001              Cotton 100%       Black  NaN   Skinny fit
# 4   0985159001              Cotton 100%       Black  NaN   Skinny fit
# 5   0985159001              Cotton 100%       Black  NaN   Skinny fit
# 6   0985159001              Cotton 100%       Black  NaN   Skinny fit
#
#    stlye_id color_id
# 0   1008549      007
# 1   1008549      007
# 2   1008549      007
# 3   1008549      007
# 4   1008549      007
# ..      ...      ...
# 2   0985159      001
# 3   0985159      001
# 4   0985159      001
# 5   0985159      001
# 6   0985159      001
#
# [1809 rows x 7 columns]

# %%
# Out:
#     product_id       color_name                 composition size       fit
# 0   1024256006  Dark denim blue      Cotton 99%, Spandex 1%  NaN  Slim fit
# 1   1024256006  Dark denim blue                 Cotton 100%  NaN  Slim fit
# 2   1024256006  Dark denim blue                 Cotton 100%  NaN  Slim fit
# 3   1024256006  Dark denim blue                 Cotton 100%  NaN  Slim fit
# 4   1024256006  Dark denim blue                 Cotton 100%  NaN  Slim fit
# ..         ...              ...                         ...  ...       ...
# 2   1024256001            Black   Polyester 65%, Cotton 35%  NaN  Slim fit
# 3   1024256001            Black   Polyester 65%, Cotton 35%  NaN  Slim fit
# 4   1024256001            Black   Polyester 65%, Cotton 35%  NaN  Slim fit
# 5   1024256001            Black   Polyester 65%, Cotton 35%  NaN  Slim fit
# 6   1024256001            Black   Polyester 65%, Cotton 35%  NaN  Slim fit
#
# [102 rows x 5 columns]

# %%
aux
# Out:
# ['Composition',
#  'Size',
#  'Art. No.',
#  'Fit',
#  'messages.garmentLength',
#  'messages.waistRise',
#  'Care instructions',
#  'Material',
#  'Description',
#  'Imported',
#  'Concept',
#  'Nice to know',
#  'Composition',
#  'Size',
#  'Art. No.',
#  'Fit',
#  'messages.garmentLength',
#  'messages.waistRise',
#  'Care instructions',
#  'Material',
#  'Description',
#  'Imported',
#  'Concept',
#  'Nice to know',
#  'Composition',
#  'Size',
#  'Art. No.',
#  'Fit',
#  'messages.garmentLength',
#  'messages.waistRise',
#  'Care instructions',
#  'Material',
#  'Description',
#  'Imported',
#  'Concept',
#  'Nice to know',
#  'Composition',
#  'Size',
#  'Art. No.',
#  'Fit',
#  'messages.garmentLength',
#  'messages.waistRise',
#  'Care instructions',
#  'Material',
#  'Description',
#  'Imported',
#  'Concept',
#  'Nice to know',
#  'Composition',
#  'Size',
#  'Art. No.',
#  'Fit',
#  'messages.garmentLength',
#  'messages.waistRise',
#  'Care instructions',
#  'Material',
#  'Description',
#  'Imported',
#  'Concept',
#  'Nice to know',
#  'Composition',
#  'Size',
#  'Art. No.',
#  'Fit',
#  'messages.garmentLength',
#  'messages.waistRise',
#  'Care instructions',
#  'Material',
#  'Description',
#  'Imported',
#  'Concept',
#  'Nice to know',
#  'Composition',
#  'Size',
#  'Art. No.',
#  'Fit',
#  'messages.garmentLength',
#  'messages.waistRise',
#  'Care instructions',
#  'Material',
#  'Description',
#  'Imported',
#  'Concept',
#  'Nice to know',
#  'Composition',
#  'Size',
#  'Art. No.',
#  'Fit',
#  'messages.garmentLength',
#  'messages.waistRise',
#  'Care instructions',
#  'Material',
#  'Description',
#  'Imported',
#  'Concept',
#  'Nice to know',
#  'Composition',
#  'Size',
#  'Art. No.',
#  'Fit',
#  'messages.garmentLength',
#  'messages.waistRise',
#  'Care instructions',
#  'Material',
#  'Description',
#  'Imported',
#  'Concept',
#  'Nice to know',
#  'Composition',
#  'Size',
#  'Art. No.',
#  'Fit',
#  'messages.garmentLength',
#  'messages.waistRise',
#  'Care instructions',
#  'Material',
#  'Description',
#  'Imported',
#  'Concept',
#  'Nice to know',
#  'Composition',
#  'Size',
#  'Art. No.',
#  'Fit',
#  'messages.garmentLength',
#  'messages.waistRise',
#  'Care instructions',
#  'Material',
#  'Description',
#  'Imported',
#  'Concept',
#  'Nice to know',
#  'Composition',
#  'Size',
#  'Art. No.',
#  'Fit',
#  'messages.garmentLength',
#  'messages.waistRise',
#  'Care instructions',
#  'Material',
#  'Description',
#  'Imported',
#  'Concept',
#  'Nice to know',
#  'Composition',
#  'Size',
#  'Art. No.',
#  'Fit',
#  'messages.garmentLength',
#  'messages.waistRise',
#  'Care instructions',
#  'Material',
#  'Description',
#  'Imported',
#  'Concept',
#  'Nice to know',
#  'Composition',
#  'Size',
#  'Art. No.',
#  'Fit',
#  'messages.garmentLength',
#  'messages.waistRise',
#  'Care instructions',
#  'Material',
#  'Description',
#  'Imported',
#  'Concept',
#  'Nice to know',
#  'Composition',
#  'Size',
#  'Art. No.',
#  'Fit',
#  'messages.garmentLength',
#  'messages.waistRise',
#  'Care instructions',
#  'Material',
#  'Description',
#  'Imported',
#  'Concept',
#  'Nice to know']

# %%
#composition
soup.find_all('dd','details-list-item')[3].get_text()
# Out:
# 'Cotton 99%, Spandex 1%'

# %%
 soup.find_all('div', class_ = 'details-attributes-list-item')[9]
# Out:
# <div class="details-attributes-list-item">
# <dt class="details-headline">Concept</dt>
# <dd class="details-list-item">DENIM</dd>
# </div>

# %%
df_color
# Out:
#    product_id        color_name
# 0  1004199001  Light denim blue
# 1  1004199002             Black
# 2  1004199003        Denim blue
# 3  1004199004             White
# 4  1004199005        Light gray

# %% [markdown]
# # DATA CLEANING

# %%
#loading the data
data = pd.read_csv('/home/guilherme/Documentos/repos/ds_ao_dev/projeto_webscraping/df_raw.csv')

#delete the columns not necessery
data = data.drop(['Unnamed: 0' ],axis=1)

#product id

data = data.dropna(subset=['product_id'])

#product category

#product name
data['products_name']= data['products_name'].apply(lambda x: x.replace(' ','_').lower())
#products_price

#já fiz o tratamento anteriomente

#product datetime


data['scrapy_datetime']= pd.to_datetime(data['scrapy_datetime'])

#style id

#color id

#color name
data['color_name']= data['color_name'].apply(lambda x: x.replace(' ','_').replace('/','_').lower() if pd.notnull(x) else x)

#Composition

data['Composition']= data['Composition'].where(~data['Composition'].str.contains('Pocket lining:',na=False) ) 

data['Composition']= data['Composition'].where(lambda x: ~x.str.contains('Shell:',na=False) )

data['Composition'] = data['Composition'].where(lambda x: ~x.str.contains('Lining:',na=False) )

#drop duplicates
#first were making drop the that are duplicates (excect the colum Composition), because the colums is duplicate
data= data.drop_duplicates(subset= ['product_id', 'products_category', 'products_name', 'products_price',
       'scrapy_datetime', 'stlye_id', 'color_id', 'color_name'],keep='last')

   
#reset index
data = data.reset_index(drop=True)


#break composition by comma (separando as composições dos materiais por coluna)
df1 = data['Composition'].str.split(',',expand=True)

#Cotton| Spandex | Polyester |  Elastomultiester
#2 etapa
#definir as colunas (organizando as colunas por máteria-prima)

#criando Dataframe vazio com o mesmo tamanho do dataframe original para prencher com as respectivas composições
df_ref = pd.DataFrame(index=np.arange(len(data) ),columns=['cotton','spandex','polyester','elastomultiester'])

#cotton
#pegando a coluna da composição cotton
df_cotton = df1[0]

#colocando o nome na coluna 
df_cotton.name = 'cotton'
#mesclando com a tabela vazia 
df_ref = pd.concat([df_ref,df_cotton],axis=1)

#dropando as colunas duplicadas
df_ref= df_ref.iloc[:,~df_ref.columns.duplicated(keep='last')]

df_ref['cotton'] = df_ref['cotton'].fillna( 'Cotton 0%' )

#polyester 

#adicionando as coluna da composição Polyester
df_polyester =df1[1].where(lambda x: x.str.contains('Polyester',na=True))

#renomeando a coluna
df_polyester.name= 'polyester'


df_ref= pd.concat([df_ref,df_polyester],axis=1)

#dropando as colunas duplicadas
df_ref= df_ref.iloc[:,~df_ref.columns.duplicated(keep='last')]

df_ref['polyester'] = df_ref['polyester'].fillna( 'Polyester 0%' )

#Elastomultiester

#coletando apenas a composição elastano
df_elastomultiester =df1[1].where(lambda x: x.str.contains('Elastomultiester',na=True))

#renomenado a coluna eslastano
df_elastomultiester.name= 'elastomultiester'


#mesclando com df_ref vazio e com a mesma quantidade de linhas que há no index
df_ref= pd.concat([df_ref,df_elastomultiester],axis=1)

#dropando as colunas duplicadas
df_ref= df_ref.iloc[:,~df_ref.columns.duplicated(keep='last')]

df_ref['elastomultiester'] = df_ref['elastomultiester'].fillna( 'Elastomultiester 0%' )

#Spandex

#coletando composição spandex da segunda coluna df1

df_spandex= df1[1].where(lambda x: x.str.contains('Spandex',na=True))

df_spandex.name = 'spandex'

#combine from spandex botth columns 1 and 2

df_spandex = df_spandex.combine_first(df1[2])


df_ref= pd.concat([df_ref,df_spandex],axis=1)

df_ref= df_ref.iloc[:,~df_ref.columns.duplicated(keep='last')]

df_ref['spandex'] = df_ref['spandex'].fillna('Spandex 0%')

#coletando composição spandex da terceira coluna do df1

#df_spandex_2= df1[2].where(lambda x: x.str.contains('Spandex',na=True))
             
#df_spandex_2.name= 'spandex'

#df_ref= pd.concat([df_ref,df_spandex_2],axis=1)

#df_ref= df_ref.iloc[:,~df_ref.columns.duplicated(keep='last')]



#final join

data= pd.concat([data,df_ref],axis=1)

#coletando apenas os numeros e transformando em números inteiros

#format composition data

#cotton
data['cotton']= data['cotton'].apply(lambda x: int(re.search('\d+',x ).group(0))/100 if pd.notnull(x) else x)

#spandex
data['spandex'] =data['spandex'].apply(lambda x: int(re.search('\d+', x).group(0)) /100 if pd.notnull(x) else x)

#polyester
data['polyester']= data['polyester'].apply(lambda x: int(re.search('\d+', x).group(0))/100 if pd.notnull(x) else x)

#elastomultiester
data['elastomultiester']=data['elastomultiester'].apply(lambda x: int(re.search('\d+', x).group(0)) /100 if pd.notnull(x) else x)

#drop columns
data= data.drop(['Composition'],axis=1)

#drop duplicates


data= data.drop_duplicates()

data.shape
